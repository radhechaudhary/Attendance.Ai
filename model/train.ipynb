# %%
import cv2
import face_recognition

# %%
image = face_recognition.load_image_file("group5.jpg")
face_locations = face_recognition.face_locations(image)

# %%
face_locations
# Out:
# [(107, 463, 159, 412),
#  (101, 319, 153, 268),
#  (108, 411, 170, 349),
#  (124, 216, 176, 164)]

# %%
group_face_encoding = face_recognition.face_encodings(image, face_locations)

# %%
group_face_encoding
# Out:
# [array([-1.35561958e-01,  5.26242442e-02,  2.54459120e-02, -7.89370481e-03,
#         -6.05943762e-02,  2.27318108e-02, -6.39792383e-02, -9.02470015e-03,
#          1.94553867e-01, -1.21481493e-01,  1.01076297e-01, -8.68671294e-03,
#         -1.76737949e-01, -9.23261642e-02, -1.50995411e-03,  9.55668315e-02,
#         -1.72831550e-01, -1.48242116e-01, -2.10750080e-03, -3.58017869e-02,
#         -1.16206165e-02,  2.48868279e-02, -1.50799565e-02,  4.89036702e-02,
#         -1.72524795e-01, -3.29782307e-01, -8.80427510e-02, -1.40546277e-01,
#          4.34803143e-02, -8.53715390e-02, -7.66486898e-02, -4.41269530e-03,
#         -1.25755921e-01, -3.99979986e-02,  3.62485275e-02,  1.99207783e-01,
#          1.43328719e-02, -3.33345756e-02,  1.59379050e-01, -1.42473886e-02,
#         -1.09346412e-01, -3.74495760e-02,  3.86634696e-04,  3.49407613e-01,
#          1.47492915e-01,  3.24701928e-02, -2.25883964e-02, -3.19650136e-02,
# ...

# %%
image = face_recognition.load_image_file("group5.jpeg")
face_locations = face_recognition.face_locations(image)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 image = face_recognition.load_image_file("group5.jpeg")
#       2 face_locations = face_recognition.face_locations(image)
#
# File ~/.conda/envs/radheenv/lib/python3.9/site-packages/face_recognition/api.py:86, in load_image_file(file, mode)
#      78 def load_image_file(file, mode='RGB'):
#      79     """
#      80     Loads an image file (.jpg, .png, etc) into a numpy array
#      81
#    (...)
#      84     :return: image contents as numpy array
#      85     """
# ---> 86     im = PIL.Image.open(file)
#      87     if mode:
#      88         im = im.convert(mode)
#
# File ~/.conda/envs/radheenv/lib/python3.9/site-packages/PIL/Image.py:3513, in open(fp, mode, formats)
#    3511 if is_path(fp):
#    3512     filename = os.fspath(fp)
# -> 3513     fp = builtins.open(filename, "rb")
# ...

# %%
my_face_encoding = face_recognition.face_encodings(image, face_locations)

# %%
my_face_encoding
# Out:
# [array([-0.16317762,  0.13677728,  0.01717451, -0.0472393 , -0.00737101,
#         -0.04181199, -0.04294157, -0.11687529,  0.16149619, -0.02797147,
#          0.29203197, -0.04409064, -0.25622773, -0.13485554, -0.00047634,
#          0.10225634, -0.1523166 , -0.10659763, -0.05927463, -0.05284591,
#          0.04283066, -0.0289091 ,  0.0292158 ,  0.1103804 , -0.14075752,
#         -0.36320531, -0.08944328, -0.20202912, -0.05355501, -0.18873496,
#          0.00100811, -0.02082819, -0.16557866, -0.07217071, -0.05107399,
#          0.019537  , -0.04656172,  0.00991737,  0.22439143,  0.05618355,
#         -0.13698661, -0.06851788,  0.02312269,  0.28064561,  0.18626237,
#         -0.0066855 ,  0.01634325, -0.06258553,  0.0974487 , -0.21225308,
#          0.00884967,  0.1464684 ,  0.14436284,  0.08765426,  0.07646387,
#         -0.10329343, -0.00633917,  0.05713874, -0.24171622,  0.0549702 ,
#         -0.00706827, -0.04706079, -0.06986698,  0.00734587,  0.2628586 ,
# ...

# %%
for encoding in group_face_encoding:
    dist = face_recognition.face_distance(encoding, my_face_encoding)
    print(face_recognition.compare_faces(encoding, my_face_encoding))
    print(dist)
# Out:
# [np.False_]
# [0.67396024]
# [np.True_]
# [0.39258]

# %%
import cv2

# %%
image = cv2.imread('image.jpg')
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

laplacian_var = cv2.Laplacian(gray, cv2.CV_64F).var()

# %%
print(laplacian_var)
# Out:
# 315.0547521971118
